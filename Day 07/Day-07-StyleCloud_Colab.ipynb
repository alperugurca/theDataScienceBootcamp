# %%
# https://fontawesome.cc/

# %%
pip install stylecloud
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.1/262.1 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.4/161.4 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 19.3 MB/s eta 0:00:00
# ...
#   Created wheel for stylecloud: filename=stylecloud-0.5.2-py3-none-any.whl size=259491 sha256=c53a9de82b20de9d23fb97469f02605a22bb08e1fcd6341ebb91e6a88333ddab
#   Stored in directory: /root/.cache/pip/wheels/aa/c8/27/9374f4fc7133015d902b5e2c75ad951edd57eb1ae948495915
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=b66b7c80c5129164dbd11884a0c0adf67f2038663f9e80da7bb730ce332b9b3c
# ...

# %%
import stylecloud as sc
import matplotlib.pyplot as plt
from IPython.display import Image

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='ch.png')

# %%
Image('ch.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-car', output_name='ch2.png')

# %%
Image('ch2.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-truck', output_name='ch3.png')

# %%
Image('ch3.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-cart-arrow-down', output_name='ch4.png')
Image('ch4.png')

# %%
#sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-magnifying-glass', output_name='ch5.png')
#Image('ch5.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-786bbd9a5f59> in <cell line: 1>()
# ----> 1 sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-magnifying-glass', output_name='ch5.png')
#       2 Image('ch5.png')
#
# /usr/local/lib/python3.10/dist-packages/stylecloud/stylecloud.py in gen_stylecloud(text, file_path, size, icon_name, palette, colors, background_color, max_font_size, max_words, stopwords, custom_stopwords, add_stopwords, icon_dir, output_name, gradient, font_path, random_state, collocations, invert_mask, pro_icon_path, pro_css_path)
#     216         text = file_to_text(file_path)
#     217
# --> 218     gen_fa_mask(icon_name, size, icon_dir, pro_icon_path, pro_css_path)
#     219
#     220     if gradient and colors is None:
#
# ...

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-star-and-crescent', output_name='ch6.png')
Image('ch6.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-check', output_name='ch7.png')
Image('ch7.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-bars', output_name='ch8.png')
Image('ch8.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-plane', output_name='ch9.png',background_color='black',colors='white')
Image('ch9.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-paper-plane', output_name='ch10.png',background_color='black',colors='white')
Image('ch10.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-fighter-jet', output_name='ch11.png',background_color='black',colors='white')
Image('ch11.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-dice', output_name='ch12.png',background_color='black',colors='white')
Image('ch12.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-cut', output_name='ch13.png',background_color='black',colors='white')
Image('ch13.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', icon_name='fas fa-leaf', output_name='ch14.png')
Image('ch14.png')
