# %%
# Üstünkörü baksanız yeterli.

# %% [markdown]
# # <font color=green>Intro to Python

# %%
# One paragraph info. Python and pandas work.

# %% [markdown]
# $ \int_a^b \frac{dx}{sinx} \theta $

# %% [markdown]
# ### Değişken Tanımla

# %%
a=5

# %%
a
# Out:
# 5

# %%
b=3

# %%
b
# Out:
# 3

# %%
c=a*b

# %%
c
# Out:
# 15

# %%
print(c)
# Out:
# 15

# %%
yil=2011

# %%
print("Merhabaaaa")
# Out:
# Merhabaaaa

# %%
for i in range(10):
    print(yil)
# Out:
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011
# 2011

# %%
"""Merhaba Dunya"""*10
# Out:
# 'Merhaba DunyaMerhaba DunyaMerhaba DunyaMerhaba DunyaMerhaba DunyaMerhaba DunyaMerhaba DunyaMerhaba DunyaMerhaba DunyaMerhaba Dunya'

# %%
#Veri Tipleri

# %%
# 1- String = Yazı metin text, tek çift, üç tırnakla yazılır ' " """ 
# 2- Integer = Tam sayı
# 3- Float = Ondalıklı sayı

# %%
'''Merha "ba"'''
# Out:
# 'Merha "ba"'

# %%
# list

# %%
list1=[1, 2, 3, "A", "B"]

# %%
#dictionary
sozluk1={"key": "pony"}

# %%
for i in list1:
        print(i)
# Out:
# 1
# 2
# 3
# A
# B

# %%
# func
fiyat=[20,30,40,50,60]

# %%
#DRY - Do not repeat yourself

# %%
def tax(x):
    return x*1.60

# %%
tax(100)
# Out:
# 160.0

# %%
for i in fiyat:
    print(tax(i))
# Out:
# 32.0
# 48.0
# 64.0
# 80.0
# 96.0

# %%
#list comprehension

# %%
[tax(x) for x in fiyat]
# Out:
# [32.0, 48.0, 64.0, 80.0, 96.0]

# %%
[x**3 for x in range(5)]
# Out:
# [0, 1, 8, 27, 64]

# %%
#Operatorler

# %%
# Aritmetik Operatorler +, -, *, /, %(Bölümden kalan), **(Üs alma),

# %%
#Logic Operators <, >, ==, !=(eşit değil), &_and, |_or,

# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 403E-E828
#
#  Directory of C:\Users\axkl1\Desktop\750$\Day 01
#
# 28.07.2024  01:08    <DIR>          .
# 28.07.2024  01:08    <DIR>          ..
# 27.07.2024  22:51    <DIR>          .ipynb_checkpoints
# 03.12.2022  13:12             6.681 catalog.xml
# 03.12.2022  13:12               335 Courses.json
# 03.12.2022  13:12               518 data.xml
# 27.07.2024  15:10            73.002 Day1StudentFiles.zip
# 03.12.2022  13:12            11.658 excel-comp-data.xlsx
# 28.07.2024  01:02            15.543 gdp.xlsx
# 28.07.2024  01:08           152.997 Intro to Python.ipynb
# 03.12.2022  13:12             5.552 sales-estimate.xlsx
# 03.12.2022  13:12             5.680 sales-funnel.xlsx
# 03.12.2022  13:12                40 test_pandas.csv
# 03.12.2022  13:12            36.864 test_pandas.db
# 03.12.2022  13:12            30.093 test_pandas.xlsm
# 03.12.2022  13:12                43 test_pandas_no_header.csv
# ...

# %%
#data frame(tablo) # csv = comma-separated values
df=pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.plot()
# Out:
# <Axes: >

# %%
toplam=0
c=0
for i in df["Age"]:
    toplam=toplam+i
    c=c+1
avg=toplam/c

print(avg)
# Out:
# nan

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df["Gender"].value_counts()
# Out:
# Gender
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Gender"].value_counts(normalize=True)
# Out:
# Gender
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
df[df["Age"]<18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df.columns=df.columns.str.upper()

# %%
df.head()
# Out:
#    PASSENGERID  SURVIVED  PCLASS  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 NAME  GENDER   AGE  SIBSP  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    PARCH            TICKET     FARE CABIN EMBARKED
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2=pd.read_excel("sales-funnel.xlsx")

# %%
#pip install xlrd

# %%
df2.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
df3=pd.read_xml("catalog.xml")

# %%
df3.head()
# Out:
#                 COMMON               BOTANICAL ZONE         LIGHT  PRICE  \
# 0            Bloodroot  Sanguinaria canadensis    4  Mostly Shady  $2.44
# 1            Columbine    Aquilegia canadensis    3  Mostly Shady  $9.37
# 2       Marsh Marigold        Caltha palustris    4  Mostly Sunny  $6.81
# 3              Cowslip        Caltha palustris    4  Mostly Shady  $9.90
# 4  Dutchman's-Breeches     Dicentra cucullaria    3  Mostly Shady  $6.44
#
#    AVAILABILITY
# 0         31599
# 1         30699
# 2         51799
# 3         30699
# 4         12099

# %%
df4=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)")[0]

# %%
df4.head()
# Out:
#                                                    0
# 0  Largest economies in the world by GDP (nominal...

# %%
df4=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)")[2]

# %%
df4
# Out:
#     Country/Territory IMF[1][13]            World Bank[14]             \
#     Country/Territory   Forecast       Year       Estimate       Year
# 0               World  109529216       2024      105435540       2023
# 1       United States   28781083       2024       27360935       2023
# 2               China   18532633  [n 1]2024       17794782  [n 3]2023
# 3             Germany    4591100       2024        4456081       2023
# 4               Japan    4110452       2024        4212945       2023
# ..                ...        ...        ...            ...        ...
# 205          Kiribati        311       2024            279       2023
# 206             Palau        308       2024            263       2023
# 207  Marshall Islands        305       2024            284       2023
# 208             Nauru        161       2024            154       2023
# 209            Tuvalu         66       2024             62       2023
#
#     United Nations[15]
# ...

# %%
df4.to_excel("gdp.xlsx")

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 403E-E828
#
#  Directory of C:\Users\axkl1\Desktop\750$\Day 01
#
# 28.07.2024  01:08    <DIR>          .
# 28.07.2024  01:08    <DIR>          ..
# 27.07.2024  22:51    <DIR>          .ipynb_checkpoints
# 03.12.2022  13:12             6.681 catalog.xml
# 03.12.2022  13:12               335 Courses.json
# 03.12.2022  13:12               518 data.xml
# 27.07.2024  15:10            73.002 Day1StudentFiles.zip
# 03.12.2022  13:12            11.658 excel-comp-data.xlsx
# 28.07.2024  01:23            15.544 gdp.xlsx
# 28.07.2024  01:08           152.997 Intro to Python.ipynb
# 03.12.2022  13:12             5.552 sales-estimate.xlsx
# 03.12.2022  13:12             5.680 sales-funnel.xlsx
# 03.12.2022  13:12                40 test_pandas.csv
# 03.12.2022  13:12            36.864 test_pandas.db
# 03.12.2022  13:12            30.093 test_pandas.xlsm
# 03.12.2022  13:12                43 test_pandas_no_header.csv
# ...

# %%
df5=pd.read_excel("gdp.xlsx")

# %%
df5
# Out:
#      Unnamed: 0  Country/Territory IMF[1][13] Unnamed: 3 World Bank[14]  \
# 0           NaN  Country/Territory   Forecast       Year       Estimate
# 1           NaN                NaN        NaN        NaN            NaN
# 2           0.0              World  109529216       2024      105435540
# 3           1.0      United States   28781083       2024       27360935
# 4           2.0              China   18532633  [n 1]2024       17794782
# ..          ...                ...        ...        ...            ...
# 207       205.0           Kiribati        311       2024            279
# 208       206.0              Palau        308       2024            263
# 209       207.0   Marshall Islands        305       2024            284
# 210       208.0              Nauru        161       2024            154
# 211       209.0             Tuvalu         66       2024             62
#
#     Unnamed: 5 United Nations[15] Unnamed: 7
# 0         Year           Estimate       Year
# ...

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_number_of_scientific_and_technical_journal_articles")

# %%
df
# Out:
# [    0                                                  1
#  0 NaN  This section needs to be updated. Please help ...,
#        Rank                              Country  \
#        Rank                              Country
#  0      1.0                                China
#  1      2.0                        United States
#  2      3.0                       United Kingdom
#  3      4.0                                India
#  4      5.0                              Germany
#  ..     ...                                  ...
#  225  226.0                               Tuvalu
#  226  227.0            Saint Pierre and Miquelon
#  227  227.0                              Tokelau
#  228  227.0  French Southern and Antarctic Lands
#  229    NaN                                World
#
#      Numbers of scientific publications (2020)
#                                          Total Per million population
#  0                                      744042                  527.0
# ...

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_number_of_scientific_and_technical_journal_articles")[1]

# %%
df.head()
# Out:
#   Rank         Country Numbers of scientific publications (2020)  \
#   Rank         Country                                     Total
# 0  1.0           China                                    744042
# 1  2.0   United States                                    624554
# 2  3.0  United Kingdom                                    198500
# 3  4.0           India                                    191590
# 4  5.0         Germany                                    174524
#
#
#   Per million population
# 0                  527.0
# 1                 1875.0
# 2                 2959.0
# 3                  138.0
# 4                 2097.0

# %%
df
# Out:
#       Rank                              Country  \
#       Rank                              Country
# 0      1.0                                China
# 1      2.0                        United States
# 2      3.0                       United Kingdom
# 3      4.0                                India
# 4      5.0                              Germany
# ..     ...                                  ...
# 225  226.0                               Tuvalu
# 226  227.0            Saint Pierre and Miquelon
# 227  227.0                              Tokelau
# 228  227.0  French Southern and Antarctic Lands
# 229    NaN                                World
#
#     Numbers of scientific publications (2020)
#                                         Total Per million population
# 0                                      744042                  527.0
# 1                                      624554                 1875.0
# 2                                      198500                 2959.0
# ...

# %%
pip install gtts
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS

# %%
text="Sen istiyor duş, verecek 100 dolar daha"
kayit=gTTS(text=text,lang="ru")
kayit.save("robot.mp3")

# %%
df=pd.read_csv("train.csv")

# %%
import seaborn as sns

# %%
sns.pairplot(df,hue="Gender")
