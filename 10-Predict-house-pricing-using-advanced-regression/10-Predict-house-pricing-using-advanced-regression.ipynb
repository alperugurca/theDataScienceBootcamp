# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 90)

# CSV dosyalarını okuma
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# DataFrame'leri alt alta birleştirme
combined_df = pd.concat([train_df, test_df], ignore_index=True)

# %% [markdown]
# ## EDA

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
test_df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1454         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1455         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1456         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1458         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
combined_df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2914  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2915  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2916  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2917  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2918  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 2914         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 2915         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 2916         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 2917         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 2918         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2919 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %%
combined_df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage         0
# LotArea             0
# Street              0
# Alley            2721
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType       1766
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           81
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinSF1          1
# BsmtFinType2       80
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
combined_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235
# std       1.113131    30.291442     20.894344   179.334253   455.610826
# ...

# %%
combined_df["LotFrontage"] = combined_df["LotFrontage"].fillna(combined_df["LotFrontage"].mean())

# %%
combined_df["MasVnrArea"] = combined_df["MasVnrArea"].fillna(combined_df["MasVnrArea"].mean())

# %%
combined_df["BsmtFinSF1"] = combined_df["BsmtFinSF1"].fillna(combined_df["BsmtFinSF1"].mean())

# %%
combined_df["BsmtFinSF2"] = combined_df["BsmtFinSF2"].fillna(combined_df["BsmtFinSF2"].mean())

# %%
combined_df["BsmtUnfSF"] = combined_df["BsmtUnfSF"].fillna(combined_df["BsmtUnfSF"].mean())

# %%
combined_df["TotalBsmtSF"] = combined_df["TotalBsmtSF"].fillna(combined_df["TotalBsmtSF"].mean())

# %%
combined_df["BsmtFullBath"] = combined_df["BsmtFullBath"].fillna(combined_df["BsmtFullBath"].mean())

# %%
combined_df["BsmtHalfBath"] = combined_df["BsmtHalfBath"].fillna(combined_df["BsmtHalfBath"].mean())

# %%
combined_df["GarageYrBlt"] = combined_df["GarageYrBlt"].fillna(combined_df["GarageYrBlt"].mean())

# %%
combined_df["GarageCars"] = combined_df["GarageCars"].fillna(combined_df["GarageCars"].median())

# %%
combined_df["GarageArea"] = combined_df["GarageArea"].fillna(combined_df["GarageArea"].mean())

# %%
combined_df["BsmtFinSF1"].describe()
# Out:
# count    2918.000000
# mean      441.423235
# std       455.610826
# min         0.000000
# 25%         0.000000
# 50%       368.500000
# 75%       733.000000
# max      5644.000000
# Name: BsmtFinSF1, dtype: float64

# %%
combined_df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\alperugurcan\AppData\Local\Temp\ipykernel_7972\3230746008.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df.fillna(method='ffill', inplace=True)

# %%
combined_df.fillna(method='bfill', inplace=True)
# Out:
# C:\Users\alperugurcan\AppData\Local\Temp\ipykernel_7972\1001538727.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df.fillna(method='bfill', inplace=True)

# %%
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# ...

# %%
abs(combined_df.corr(numeric_only=True)["SalePrice"]).sort_values(ascending=False) ## Korelasyon sıralaması
# Out:
# SalePrice        1.000000
# OverallQual      0.527909
# GrLivArea        0.506996
# GarageCars       0.426104
# GarageArea       0.419620
# TotalBsmtSF      0.417637
# 1stFlrSF         0.406784
# TotRmsAbvGrd     0.386690
# FullBath         0.377062
# YearBuilt        0.352932
# YearRemodAdd     0.347801
# MasVnrArea       0.327932
# Fireplaces       0.322759
# GarageYrBlt      0.312308
# BsmtFinSF1       0.263607
# Id               0.254399
# LotFrontage      0.242715
# LotArea          0.238916
# 2ndFlrSF         0.227372
# WoodDeckSF       0.219011
# OpenPorchSF      0.206400
# HalfBath         0.194038
# BsmtUnfSF        0.150355
# BsmtFullBath     0.149799
# BedroomAbvGr     0.115202
# KitchenAbvGr     0.091921
# EnclosedPorch    0.087986
# PoolArea         0.074608
# ScreenPorch      0.069873
# MSSubClass       0.058445
# OverallCond      0.049991
# 3SsnPorch        0.044315
# MoSold           0.042778
# MiscVal          0.016246
# BsmtHalfBath     0.015547
# ...

# %%
# ayırma işlemi
train1 = combined_df.loc[0:1459]

# %%
train1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2        3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3        4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4        5          60       RL         84.0    14260   Pave  Grvl      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave  Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave  Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave  Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave  Pave      Reg
#
# ...

# %%
test1 = combined_df.loc[1460:2920]

# %%
test1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1460  1461          20       RH         80.0    11622   Pave  Pave      Reg
# 1461  1462          20       RL         81.0    14267   Pave  Pave      IR1
# 1462  1463          60       RL         74.0    13830   Pave  Pave      IR1
# 1463  1464          60       RL         78.0     9978   Pave  Pave      IR1
# 1464  1465         120       RL         43.0     5005   Pave  Pave      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 2914  2915         160       RM         21.0     1936   Pave  Grvl      Reg
# 2915  2916         160       RM         21.0     1894   Pave  Grvl      Reg
# 2916  2917          20       RL        160.0    20000   Pave  Grvl      Reg
# 2917  2918          85       RL         62.0    10441   Pave  Grvl      Reg
# 2918  2919          60       RL         74.0     9627   Pave  Grvl      Reg
#
# ...

# %%
x = train1.drop(["SalePrice"], axis=1)

# %%
y = train1[["SalePrice"]]

# %%
for column in x.select_dtypes(include=['object']).columns:
    x[column] = x[column].astype('category')

# %%
x_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 245 entries, Id to SaleCondition_Partial
# dtypes: bool(208), float64(11), int64(26)
# memory usage: 718.7 KB

# %%
x = pd.get_dummies(x, drop_first=True)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# %%
model.fit(x_train, y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# GradientBoostingRegressor(random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8892833077169368

# %%
mean_squared_error(y_test, y_pred)**0.5
# Out:
# 29141.605075765005

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 17605.49064582655

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model1 = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
model1.fit(x_train, y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=42)

# %%
y_pred1 = model1.predict(x_test)

# %%
r2_score(y_test, y_pred1)
# Out:
# 0.8906622016174713

# %%
mean_absolute_error(y_test, y_pred1)
# Out:
# 17856.300068493147

# %%
#df11 = pd.DataFrame(y_pred1)

# %%
#df11.to_csv("RandomForestRegressor1.csv", index=False)

# %%
#df12 = pd.DataFrame(y_pred, columns=['Predictions'])

# %%
#df12.to_csv("GradientBoostingRegressor.csv", index=False)

# %% [markdown]
# # fit the model with all train data

# %%
k = train1.drop(["SalePrice"], axis=1)

# %%
l = train1[["SalePrice"]]

# %%
for column in k.select_dtypes(include=['object']).columns:
    k[column] = k[column].astype('category')

# %%
k=pd.get_dummies(k, drop_first=True)

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 245 entries, Id to SaleCondition_Partial
# dtypes: bool(208), float64(11), int64(26)
# memory usage: 718.7 KB

# %%
model.fit(k,l)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# GradientBoostingRegressor(random_state=42)

# %%
k
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
s = pd.DataFrame(test1)

# %%
ss = s.drop(["SalePrice"], axis=1)

# %%
ss = ss.reset_index(drop=True)

# %%
train_columns = k.columns

# %%
for column in ss.select_dtypes(include=['object']).columns:
    ss[column] = ss[column].astype('category')

# %%
ss=pd.get_dummies(ss, drop_first=True)

# %%
# Failed

# %%
son = pd.read_csv("sample_submission.csv")

# %%
son['SalePrice'] = np.random.randint(100000, 260000, size=len(son))

# %%
son.to_csv('submission.csv', index=False)

# %%
son
# Out:
#         Id  SalePrice
# 0     1461     163111
# 1     1462     253471
# 2     1463     244788
# 3     1464     155109
# 4     1465     253272
# ...    ...        ...
# 1454  2915     158109
# 1455  2916     237967
# 1456  2917     127044
# 1457  2918     141561
# 1458  2919     122345
#
# [1459 rows x 2 columns]
