# %% [markdown]
# # Recommendation Systems

# %%
import pandas as pd
import numpy as np

# %%
r_columns = ['user_id', 'movie_id', 'rating']
ratings = pd.read_csv('ml-100k/u.data', sep='\t', header=None, names=r_columns,usecols=range(3))

# %%
ratings
# Out:
#         user_id  movie_id  rating
# 0             0        50       5
# 1             0       172       5
# 2             0       133       1
# 3           196       242       3
# 4           186       302       3
# ...         ...       ...     ...
# 99998       880       476       3
# 99999       716       204       5
# 100000      276      1090       1
# 100001       13       225       2
# 100002       12       203       3
#
# [100003 rows x 3 columns]

# %%
r_cols=['movie_id', 'title']
movies=pd.read_csv('ml-100k/u.item', encoding='iso-8859-1',sep='|', header=None,names=r_cols,usecols=range(2))

# %%
movies
# Out:
#       movie_id                                      title
# 0            1                           Toy Story (1995)
# 1            2                           GoldenEye (1995)
# 2            3                          Four Rooms (1995)
# 3            4                          Get Shorty (1995)
# 4            5                             Copycat (1995)
# ...        ...                                        ...
# 1677      1678                          Mat' i syn (1997)
# 1678      1679                           B. Monkey (1998)
# 1679      1680                       Sliding Doors (1998)
# 1680      1681                        You So Crazy (1994)
# 1681      1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
r_cols=['user_id', 'Age', 'Gender', 'Profession', 'Zipcode']
user = pd.read_table(r'C:\Users\alperugurcan\Desktop\750$\Day 11\ml-100k\u.user.txt', sep='|', names=r_cols)

# %%
user
# Out:
#      user_id  Age Gender     Profession Zipcode
# 0          1   24      M     technician   85711
# 1          2   53      F          other   94043
# 2          3   23      M         writer   32067
# 3          4   24      M     technician   43537
# 4          5   33      F          other   15213
# ..       ...  ...    ...            ...     ...
# 938      939   26      F        student   33319
# 939      940   32      M  administrator   02215
# 940      941   20      M        student   97229
# 941      942   48      F      librarian   78209
# 942      943   22      M        student   77841
#
# [943 rows x 5 columns]

# %%
user.iloc[195]
# Out:
# user_id          196
# Age               49
# Gender             M
# Profession    writer
# Zipcode        55105
# Name: 195, dtype: object

# %%
movies.iloc[241]
# Out:
# movie_id             242
# title       Kolya (1996)
# Name: 241, dtype: object

# %%
ratings = pd.merge(movies,ratings) # sütun isimlerinden birleştir

# %%
ratings
# Out:
#         movie_id                                      title  user_id  rating
# 0              1                           Toy Story (1995)      308       4
# 1              1                           Toy Story (1995)      287       5
# 2              1                           Toy Story (1995)      148       4
# 3              1                           Toy Story (1995)      280       4
# 4              1                           Toy Story (1995)       66       3
# ...          ...                                        ...      ...     ...
# 99998       1678                          Mat' i syn (1997)      863       1
# 99999       1679                           B. Monkey (1998)      863       3
# 100000      1680                       Sliding Doors (1998)      863       2
# 100001      1681                        You So Crazy (1994)      896       3
# 100002      1682  Scream of Stone (Schrei aus Stein) (1991)      916       3
#
# [100003 rows x 4 columns]

# %%
ratings.title.value_counts()
# Out:
# title
# Star Wars (1977)                                584
# Contact (1997)                                  509
# Fargo (1996)                                    508
# Return of the Jedi (1983)                       507
# Liar Liar (1997)                                485
#                                                ...
# Tigrero: A Film That Was Never Made (1994)        1
# Eye of Vichy, The (Oeil de Vichy, L') (1993)      1
# Promise, The (Versprechen, Das) (1994)            1
# To Cross the Rubicon (1991)                       1
# Scream of Stone (Schrei aus Stein) (1991)         1
# Name: count, Length: 1664, dtype: int64

# %%
ratings.movie_id.nunique()
# Out:
# 1682

# %%
# Filmlerin korelasyonlarına göre tavsiye

# %%
movie_ratings = ratings.pivot_table(index=['user_id'], columns=['title'], values='rating')

# %%
 movie_ratings # Matrix Factorization
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# ...                      ...         ...                          ...
# 939                      NaN         NaN                          NaN
# 940                      NaN         NaN                          NaN
# 941                      NaN         NaN                          NaN
# 942                      NaN         NaN                          NaN
# 943                      NaN         NaN                          2.0
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 0                                        NaN                           NaN
# 1                                        3.0                           4.0
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# ...                                      ...                           ...
# 939                                      NaN                           NaN
# 940                                      NaN                           NaN
# 941                                      NaN                           NaN
# 942                                      NaN                           3.0
# 943                                      NaN                           NaN
#
# title    3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# user_id
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                1.0                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# ...                                              ...                   ...
# 939                                              NaN                   NaN
# 940                                              NaN                   NaN
# 941                                              NaN                   NaN
# 942                                              NaN                   3.0
# 943                                              NaN                   NaN
#
# title    ...  Yankee Zulu (1994)  Year of the Horse (1997)  \
# user_id  ...
# 0        ...                 NaN                       NaN
# 1        ...                 NaN                       NaN
# 2        ...                 NaN                       NaN
# 3        ...                 NaN                       NaN
# 4        ...                 NaN                       NaN
# ...      ...                 ...                       ...
# 939      ...                 NaN                       NaN
# 940      ...                 NaN                       NaN
# 941      ...                 NaN                       NaN
# 942      ...                 NaN                       NaN
# 943      ...                 NaN                       NaN
#
# title    You So Crazy (1994)  Young Frankenstein (1974)  Young Guns (1988)  \
# user_id
# 0                        NaN                        NaN                NaN
# 1                        NaN                        5.0                3.0
# 2                        NaN                        NaN                NaN
# 3                        NaN                        NaN                NaN
# 4                        NaN                        NaN                NaN
# ...                      ...                        ...                ...
# 939                      NaN                        NaN                NaN
# 940                      NaN                        NaN                NaN
# 941                      NaN                        NaN                NaN
# 942                      NaN                        NaN                NaN
# 943                      NaN                        NaN                4.0
#
# title    Young Guns II (1990)  Young Poisoner's Handbook, The (1995)  \
# user_id
# 0                         NaN                                    NaN
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# ...                       ...                                    ...
# 939                       NaN                                    NaN
# 940                       NaN                                    NaN
# 941                       NaN                                    NaN
# 942                       NaN                                    NaN
# 943                       3.0                                    NaN
#
# title    Zeus and Roxanne (1997)  unknown  Á köldum klaka (Cold Fever) (1994)
# user_id
# 0                            NaN      NaN                                 NaN
# 1                            NaN      4.0                                 NaN
# 2                            NaN      NaN                                 NaN
# 3                            NaN      NaN                                 NaN
# 4                            NaN      NaN                                 NaN
# ...                          ...      ...                                 ...
# 939                          NaN      NaN                                 NaN
# 940                          NaN      NaN                                 NaN
# 941                          NaN      NaN                                 NaN
# 942                          NaN      NaN                                 NaN
# 943                          NaN      NaN                                 NaN
#
# [944 rows x 1664 columns]

# %%
movie_ratings['Star Wars (1977)']
# Out:
# user_id
# 0      5.0
# 1      5.0
# 2      5.0
# 3      NaN
# 4      5.0
#       ...
# 939    NaN
# 940    4.0
# 941    NaN
# 942    5.0
# 943    4.0
# Name: Star Wars (1977), Length: 944, dtype: float64

# %%
starwars_ratings = movie_ratings['Star Wars (1977)']

# %%
starwars_ratings.value_counts()
# Out:
# Star Wars (1977)
# 5.0    326
# 4.0    176
# 3.0     57
# 2.0     16
# 1.0      9
# Name: count, dtype: int64

# %%
movie_ratings[['101 Dalmatians (1996)', 'Star Wars (1977)']].corr() # 2 film korelasyonu
# Out:
# title                  101 Dalmatians (1996)  Star Wars (1977)
# title
# 101 Dalmatians (1996)               1.000000          0.211132
# Star Wars (1977)                    0.211132          1.000000

# %%
movie_ratings.corrwith(starwars_ratings)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# title
# 'Til There Was You (1997)                0.872872
# 1-900 (1994)                            -0.645497
# 101 Dalmatians (1996)                    0.211132
# 12 Angry Men (1957)                      0.184289
# 187 (1997)                               0.027398
#                                            ...
# Young Guns II (1990)                     0.228615
# Young Poisoner's Handbook, The (1995)   -0.007374
# Zeus and Roxanne (1997)                  0.818182
# unknown                                  0.723123
# Á köldum klaka (Cold Fever) (1994)            NaN
# Length: 1664, dtype: float64

# %%
similar_movies = movie_ratings.corrwith(starwars_ratings)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2889: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
similar_movies = similar_movies.dropna()

# %%
similar_movies.sort_values(ascending=False)
# Out:
# title
# Hollow Reed (1996)                                                                   1.0
# Stripes (1981)                                                                       1.0
# Beans of Egypt, Maine, The (1994)                                                    1.0
# Safe Passage (1994)                                                                  1.0
# Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)    1.0
#                                                                                     ...
# For Ever Mozart (1996)                                                              -1.0
# Frankie Starlight (1995)                                                            -1.0
# I Like It Like That (1994)                                                          -1.0
# American Dream (1990)                                                               -1.0
# Theodore Rex (1995)                                                                 -1.0
# Length: 1410, dtype: float64

# %%
movie_stats=ratings.groupby('title').agg({'rating':[np.size,np.mean]})
# Out:
# C:\Users\alperugurcan\AppData\Local\Temp\ipykernel_11760\2407068517.py:1: FutureWarning: The provided callable <function mean at 0x000002BFC400F240> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   movie_stats=ratings.groupby('title').agg({'rating':[np.size,np.mean]})

# %%
movie_stats.head()
# Out:
#                           rating
#                             size      mean
# title
# 'Til There Was You (1997)      9  2.333333
# 1-900 (1994)                   5  2.600000
# 101 Dalmatians (1996)        109  2.908257
# 12 Angry Men (1957)          125  4.344000
# 187 (1997)                    41  3.024390

# %%
popular_movies=movie_stats[movie_stats['rating']['size']>100]

# %%
popular_movies.sort_values(('rating','mean'),ascending=False)
# Out:
#                                  rating
#                                    size      mean
# title
# Close Shave, A (1995)               112  4.491071
# Schindler's List (1993)             298  4.466443
# Wrong Trousers, The (1993)          118  4.466102
# Casablanca (1942)                   243  4.456790
# Shawshank Redemption, The (1994)    283  4.445230
# ...                                 ...       ...
# Spawn (1997)                        143  2.615385
# Event Horizon (1997)                127  2.574803
# Crash (1996)                        128  2.546875
# Jungle2Jungle (1997)                132  2.439394
# Cable Guy, The (1996)               106  2.339623
#
# [334 rows x 2 columns]

# %%
popular_movies.columns = popular_movies.columns.get_level_values(0)
df = popular_movies.join(pd.DataFrame(similar_movies))

# %%
df = df.rename(columns={df.columns[2]: "similarity"})

# %%
df
# Out:
#                                               rating    rating  similarity
# title
# 101 Dalmatians (1996)                            109  2.908257    0.211132
# 12 Angry Men (1957)                              125  4.344000    0.184289
# 2001: A Space Odyssey (1968)                     259  3.969112    0.230884
# Absolute Power (1997)                            127  3.370079    0.085440
# Abyss, The (1989)                                151  3.589404    0.203709
# ...                                              ...       ...         ...
# Willy Wonka and the Chocolate Factory (1971)     326  3.631902    0.221902
# Wizard of Oz, The (1939)                         246  4.077236    0.266335
# Wrong Trousers, The (1993)                       118  4.466102    0.216204
# Young Frankenstein (1974)                        200  3.945000    0.192589
# Young Guns (1988)                                101  3.207921    0.186377
#
# [334 rows x 3 columns]

# %%
df.sort_values(["similarity"],ascending=False).head(20)
# Out:
#                                                     rating    rating  \
# title
# Star Wars (1977)                                       584  4.359589
# Empire Strikes Back, The (1980)                        368  4.206522
# Return of the Jedi (1983)                              507  4.007890
# Raiders of the Lost Ark (1981)                         420  4.252381
# Austin Powers: International Man of Mystery (1997)     130  3.246154
# Sting, The (1973)                                      241  4.058091
# Indiana Jones and the Last Crusade (1989)              331  3.930514
# Pinocchio (1940)                                       101  3.673267
# Frighteners, The (1996)                                115  3.234783
# L.A. Confidential (1997)                               297  4.161616
# Wag the Dog (1997)                                     137  3.510949
# Dumbo (1941)                                           123  3.495935
# Bridge on the River Kwai, The (1957)                   165  4.175758
# Philadelphia Story, The (1940)                         104  4.115385
# Miracle on 34th Street (1994)                          101  3.722772
# E.T. the Extra-Terrestrial (1982)                      300  3.833333
# Mystery Science Theater 3000: The Movie (1996)         130  3.430769
# Cinderella (1950)                                      129  3.581395
# Batman (1989)                                          201  3.427861
# Swingers (1996)                                        157  3.828025
#
#                                                     similarity
# title
# Star Wars (1977)                                      1.000000
# Empire Strikes Back, The (1980)                       0.748353
# Return of the Jedi (1983)                             0.672556
# Raiders of the Lost Ark (1981)                        0.536117
# Austin Powers: International Man of Mystery (1997)    0.377433
# Sting, The (1973)                                     0.367538
# Indiana Jones and the Last Crusade (1989)             0.350107
# Pinocchio (1940)                                      0.347868
# Frighteners, The (1996)                               0.332729
# L.A. Confidential (1997)                              0.319065
# Wag the Dog (1997)                                    0.318645
# Dumbo (1941)                                          0.317656
# Bridge on the River Kwai, The (1957)                  0.316580
# Philadelphia Story, The (1940)                        0.314272
# Miracle on 34th Street (1994)                         0.310921
# E.T. the Extra-Terrestrial (1982)                     0.303619
# Mystery Science Theater 3000: The Movie (1996)        0.301809
# Cinderella (1950)                                     0.299163
# Batman (1989)                                         0.289344
# Swingers (1996)                                       0.289310
